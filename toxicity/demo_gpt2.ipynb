# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, GPT2Tokenizer
from fancy_einsum import einsum

# %%
model_name = "meta-llama/Llama-3.1-8B"
model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
print(model)
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
# )

# %%
print(model)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=3072, nx=1024)
#           (c_proj): Conv1D(nf=1024, nx=1024)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=4096, nx=1024)
#           (c_proj): Conv1D(nf=1024, nx=4096)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50257, bias=False)
# )

# %%
token_embeds = model.model.embed_tokens.weight
value_vectors = torch.cat(
    [
        model.model.h[layer_idx].mlp.down_proj.weight
        for layer_idx in range(model.config.num_hidden_layers)
    ],
    dim=0,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       1 token_embeds = model.model.embed_tokens.weight
#       2 value_vectors = torch.cat(
#       3     [
# ----> 4         model.transformer.h[layer_idx].mlp.down_proj.weight
#       5         for layer_idx in range(model.config.num_hidden_layers)
#       6     ],
#       7     dim=0,
#       8 )
#
# File /data/kebl6672/miniconda3/envs/toxic/lib/python3.12/site-packages/torch/nn/modules/module.py:1688, in Module.__getattr__(self, name)
#    1686     if name in modules:
#    1687         return modules[name]
# -> 1688 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'LlamaForCausalLM' object has no attribute 'transformer'

# %%
seed_token_pos = ["happy", "joy", " happy", " joy", " smile"]
seed_token_neg = [" sad", " angry", " disgust"]

pos_token_id = [tokenizer.encode(tok)[0] for tok in seed_token_pos]
neg_token_id = [tokenizer.encode(tok)[0] for tok in seed_token_neg]

print(pos_token_id)
print(neg_token_id)

pos_embed = token_embeds[pos_token_id].mean(dim=0)
neg_embed = token_embeds[neg_token_id].mean(dim=0)
# Out:
# [34191, 2633, 3772, 8716, 8212]
# [6507, 7954, 16234]

# %%
def unembed_to_text(vector, model, tokenizer, k=10):
    norm = model.transformer.ln_f
    lm_head = model.lm_head.weight
    dots = einsum("vocab d_model, d_model -> vocab", lm_head, norm(vector))
    top_k = dots.topk(k).indices
    return tokenizer.batch_decode(top_k, skip_special_tokens=True)

# %%
k = 20
norm = model.transformer.ln_f

target_vec = pos_embed - neg_embed
dot_prods = einsum("value_vecs d_model, d_model -> value_vecs", norm(value_vectors), target_vec)
top_value_vecs = dot_prods.topk(k=num_tp_vecs).indices
for vec_idx in top_value_vecs:
    print(f"Value vec: Layer {vec_idx // 4096}, index {vec_idx % 4096}")
    print(unembed_to_text(value_vectors[vec_idx], model, tokenizer))
# Out:
# Value vec: Layer 20, index 988
# [' secure', ' successful', ' successfully', ' satisfactory', ' optimal', ' improved', ' optim', ' perfected', ' excellent', ' efficient']
# Value vec: Layer 16, index 3208
# [' peaceful', ' stable', ' satisfactory', ' good', ' trustworthy', ' safe', ' reassured', ' credibility', 'Safe', ' impartial']
# Value vec: Layer 13, index 2434
# [' positives', ' advant', ' blessed', ' mirac', ' upl', ' pristine', ' bright', ' smiles', ' buoy', ' boon']
# Value vec: Layer 17, index 3439
# [' Congratulations', 'osponsors', 'Congratulations', ' Honor', 'aug', ' enriched', ' Excellence', ' rewarded', ' Blossom', ' Celebr']
# Value vec: Layer 15, index 301
# [' collaborations', ' achievements', ' excellence', ' breakthrough', ' Inspired', ' Excellence', ' inspired', ' Aub', ' amazing', ' Citation']
# Value vec: Layer 23, index 1438
# ['hari', ' externalToEVAOnly', 'perm', 'ifty', 'kin', ' Atomic', 'ourced', 'pac', '=-=-=-=-=-=-=-=-', 'allows']
# Value vec: Layer 13, index 2488
# [' unaffected', ' antioxid', 'but', ' flourishing', ' but', ' plent', ' reassuring', ' intact', ' plentiful', 'However']
# Value vec: Layer 16, index 3773
# [' enjoying', ' joy', ' exhilar', ' enjoyed', ' enjoyment', ' pleasures', ' delight', ' enjoy', ' glorious', ' enjoys']
# Value vec: Layer 17, index 3195
# [' productive', ' victories', ' success', ' favourable', ' brill', ' satisfactory', ' clarity', ' successes', ' positive', ' reassuring']
# Value vec: Layer 14, index 3305
# [' sanct', ' dign', ' dignity', ' vitality', 'tesy', ' honour', 'Faith', ' colleg', 'Merit', ' prosper']
# Value vec: Layer 13, index 2613
# [' compliment', ' amazing', ' insights', ' inspiring', ' unparalleled', ' unmatched', ' innovative', ' synergy', ' compliments', ' awesome']
# Value vec: Layer 16, index 1037
# [' benefits', 'benef', ' complimentary', ' benefit', ' generous', ' rehabilitation', 'benefit', ' Benefits', ' improvements', ' rehabilit']
# Value vec: Layer 17, index 397
# [' entr', ' Dian', ' attraction', ' congr', 'larg', ' stimulation', ' Peng', 'angelo', ' collaborations', ' Celebr']
# Value vec: Layer 16, index 755
# [' Blessing', 'ellation', 'isSpecialOrderable', ' Bless', 'eness', '++++++++++++++++', ' Elev', 'ogle', 'eral', 'ede']
# Value vec: Layer 16, index 2862
# [' satisf', ' positively', ' trustworthy', ' favorably', ' prosper', ' Airl', ' praise', ' praises', ' promot', ' trust']
# Value vec: Layer 16, index 151
# [' smoothly', ' seamlessly', ' effortlessly', ' seamless', ' confidently', 'esty', ' smooth', ' trustworthy', ' safely', ' securely']
# Value vec: Layer 16, index 588
# [' innocent', ' Palestin', ' civilians', ' democracy', ' welf', ' peaceful', ' nonviolent', ' moms', ' democratic', ' innoc']
# Value vec: Layer 14, index 1049
# [' rejuven', ' improved', ' restored', 'Benef', ' prosper', 'tesy', ' opportunities', ' boon', ' enjoying', ' mirac']
# Value vec: Layer 17, index 2033
# ['Austral', 'confidence', 'onomy', 'accompan', 'strength', 'Joy', 'YD', ' LEVEL', ' encouragement', ' maximizing']
# Value vec: Layer 13, index 670
# [' hoped', ' semblance', 'ensible', ' hope', ' valiant', ' calmed', ' allev', ' respectable', 'Hope', 'ensibly']
# Value vec: Layer 21, index 3016
# [' transc', 'entric', 'endi', ' Spac', 'iquid', 'erest', ' Vive', ' Hub', ' Hab', 'earable']
# Value vec: Layer 18, index 3013
# ['sign', 'cons', 'part', 'sh', 'st', 'comb', 'we', 'con', 'rest', 'main']
# Value vec: Layer 18, index 2898
# [' humane', ' trustworthy', ' responsibly', ' clean', ' balanced', ' respectful', ' safeguards', ' unbiased', ' sturdy', ' stabilized']
# Value vec: Layer 13, index 2011
# [' smooth', ' humane', ' equitable', ' stabilized', ' clean', ' calmed', ' soothing', ' secure', 'nect', ' smoothly']
# Value vec: Layer 14, index 3052
# [' Vulkan', ' fluent', ' richest', ' lucid', ' convinc', ' afforded', ' empowered', ' spacious', ' generous', ' rejuven']
# Value vec: Layer 15, index 2474
# [' cooperation', ' relationships', ' Relationship', ' fruitful', ' satisfactory', ' good', ' success', ' successes', ' friendships', ' collaboration']
# Value vec: Layer 21, index 238
# ['¯¯¯¯', '¯¯', ' 神', ' CHR', 'gest', ' 4090', '¯', '*=-', ' OCT', ' DRAGON']
# Value vec: Layer 19, index 2283
# [' Polaris', '�', 'rients', 'mable', ' Balanced', ' Blueprint', ' fres', ' lucid', ' Philos', 'nir']
# Value vec: Layer 23, index 3963
# ['�', 'ーテ', '||||', '\\\\\\\\\\\\\\\\', '闘', '=-=-=-=-', ' ��������', '装', '�', '=-=-']
# Value vec: Layer 18, index 342
# [' enrich', ' creativity', ' diversity', ' Unique', ' enriched', ' richness', ' limitless', 'expression', ' uniqueness', ' individuality']
# Value vec: Layer 19, index 1494
# ['def', 'dis', 'custom', 'cont', 'limited', 'pre', 'comp', 'capacity', 'special', 'being']
# Value vec: Layer 14, index 3228
# ['', '--------------------------------------------------------', '________________________', ' ®', '********************************', '……………………', '————————————————', ' amen', '------------------------------------------------', 'endix']
# Value vec: Layer 23, index 1287
# ['advertising', 'Synopsis', 'Shares', 'Norm', 'Honest', 'Activ', 'Austral', 'Recomm', 'Gall', 'Balt']
# Value vec: Layer 18, index 1369
# ['mble', ' encour', ' Gemini', ' Illust', 'bilt', ' congratulated', ' commemor', ' Veterinary', 'iversary', 'alli']
# Value vec: Layer 12, index 735
# [' mirac', ' restored', ' gracious', ' intact', ' cushion', ' repaired', ' regained', ' equitable', 'conservancy', ' recovered']
# Value vec: Layer 22, index 602
# ['cu', 'those', 'it', 'missing', 'Ep', 'its', 'easy', 'perhaps', 'Min', 'Ur']
# Value vec: Layer 15, index 1968
# [' dividend', ' quota', ' dividends', ' quotas', ' optimizing', ' stocking', ' Efficiency', ' aspir', 'rowth', ' entr']
# Value vec: Layer 9, index 2395
# ['ability', 'ment', 'ables', 'able', 'ments', 'ings', 'tion', 'ees', 'liness', 'abilities']
# Value vec: Layer 10, index 1238
# [' calm', ' Spirit', ' wholes', ' reconc', 'cellence', ' fulfilled', ' calmed', ' gracious', ' restored', ' dign']
# Value vec: Layer 15, index 2026
# [' harmless', ' innocuous', ' benign', ' gentle', ' humble', ' nic', ' mundane', ' mild', ' modest', ' moderate']
# Value vec: Layer 20, index 2352
# ['specific', 'carry', 'great', 'first', 'turned', 'straight', 'large', 'dep', 'trans', 'prem']
# Value vec: Layer 23, index 3788
# ['uilt', 'izont', 'avid', 'raz', 'oided', 'hai', 'answered', 'older', 'render', 'seen']
# Value vec: Layer 13, index 527
# [' Reborn', ' listened', 'adin', ' Pal', ' listening', ' Fior', ' Chamberlain', ' Nik', ' emulation', ' Aven']
# Value vec: Layer 20, index 3098
# [' Leading', ' Explan', ' Possibly', ' Lots', ' Newly', ' Supporters', ' Putting', ' Measures', ' Certain', ' Including']
# Value vec: Layer 17, index 1133
# [' intact', 'surv', ' survive', ' unaffected', ' ok', ' survives', ' survived', ' Surv', ' remain', ' stays']
# Value vec: Layer 21, index 665
# ['helps', 'ii', 'igm', 'amily', 'jen', ' distingu', 'iland', 'iken', 'ait', ' helicop']
# Value vec: Layer 22, index 2131
# [' unlocked', ' curated', 'aturated', ' Cosponsors', ' Anders', ' Puzz', 'ounter', ' Linux', ' Kamp', ' Prosper']
# Value vec: Layer 17, index 1744
# [' requirements', ' Designed', ' commitments', ' indo', ' dedication', ' digitally', ' apprentices', ' budgets', ' additive', ' enthusiastically']
# Value vec: Layer 22, index 1014
# ['Ther', 'Forest', 'Atl', 'Woman', 'Offic', 'Community', 'Austral', 'Disney', 'Beck', 'Virgin']
# Value vec: Layer 19, index 2644
# [' ceremony', ' Medals', ' ceremonies', 'antry', ' Grammy', ' Cere', ' celebration', ' Celebration', ' Parade', ' celebrations']
# Value vec: Layer 14, index 944
# [' balanced', ' thorough', ' respectful', ' graceful', ' gracious', ' faithfully', ' manageable', ' careful', ' sturdy', ' orderly']
# Value vec: Layer 21, index 3234
# [' development', ' rehabilitation', ' developmental', ' rehab', ' rehabilit', ' divers', ' Development', 'development', ' regeneration', ' redevelop']
# Value vec: Layer 19, index 3961
# ['orge', 'rients', ' Activate', 'resents', 'itialized', '8000', 'ォ', 'omez', 'sbm', 'ocal']
# Value vec: Layer 21, index 2738
# ['ォ', 'ather', 'aryn', 'agne', 'pires', 'earances', 'aug', 'ーン', ' Princ', '=$']
# Value vec: Layer 22, index 3000
# ['49', '52', '48', '47', '61', '51', '69', '46', '41', '37']
# Value vec: Layer 13, index 2193
# [' Minor', 'abo', 'paren', ' LAST', ' Eagle', 'mir', 'buck', 'abe', ' FIRST', ' braces']
# Value vec: Layer 7, index 3397
# ['eness', 'house', 'Aid', 'box', 'beat', ' Meal', 'HOU', 'pex', 'lap', 'shed']
# Value vec: Layer 11, index 1888
# [' uncond', ' essentials', ' equitable', ' sanity', ' trustworthy', ' properly', ' unconditional', ' authentic', ' complement', ' purified']
# Value vec: Layer 20, index 370
# ['H', 'B', 'O', 'W', 'w', 'K', 'V', 'F', 'X', 'b']
# Value vec: Layer 19, index 1135
# ['english', 'united', 'wb', 'bt', 'vp', 'gp', 'dm', 'mc', 'jp', 'gd']
# Value vec: Layer 15, index 1546
# ['erning', ' liberating', ' principled', ' humane', ' honorable', ' cooper', ' safeguards', ' scrut', 'Explore', ' constructive']
# Value vec: Layer 19, index 3446
# ['free', ' minimized', ' neutrality', ' spared', 'peace', ' minimizing', ' minim', 'less', ' minimal', ' avoided']
# Value vec: Layer 15, index 3030
# ['ensical', ' aware', ' coherent', ' spared', ' elig', ' refund', ' acceptable', ' accurate', ' adequately', ' redeem']
# Value vec: Layer 16, index 2108
# [' elig', ' optimal', 'payer', ' arrang', 'iage', ' Citiz', 'iversal', 'iev', ' optimum', 'actionDate']
# Value vec: Layer 9, index 2645
# [' Deluxe', ' Sapp', ' Hendricks', ' Vlad', ' Particip', 'cko', 'Particip', ' Rus', ' Haw', 'Advanced']
# Value vec: Layer 20, index 1211
# ['Advertisement', 'advertising', 'Spoiler', 'favorite', 'Advertisements', 'Premium', 'Contribut', 'Cert', 'Offline', 'Lind']
# Value vec: Layer 20, index 3784
# ['SIGN', 'ーティ', '________________________________________________________________', 'SPONSORED', '________________________________', 'RPG', 'Facebook', 'Maps', 'CBC', '¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯']
# Value vec: Layer 14, index 3573
# ['kins', ' innocent', ' sanity', 'forth', 'change', ' Turtles', 'Save', 'OSP', 'mb', ' Nile']
# Value vec: Layer 23, index 1269
# ['release', 'pass', 'state', 'tap', 'slot', 'cur', 'travel', 'share', 'battle', 'strength']
# Value vec: Layer 20, index 654
# ['matic', 'bats', 'lins', 'ead', 'hop', ' Cind', 'th', 'question', 'bilt', 'mented']
# Value vec: Layer 17, index 2886
# [' Sacrament', ' sacrament', ' Christ', ' Holy', ' Incarn', ' Sacred', ' sac', ' baptism', 'Holy', ' Blessed']
# Value vec: Layer 14, index 3936
# [' Payments', ' IoT', ' actu', ' savings', ' Devices', 'consumer', ' consumers', ' Savings', ' payments', ' acceler']
# Value vec: Layer 13, index 2186
# ['erning', 'Americ', '"}],"', 'Balt', 'Insp', 'Explore', ' Volunte', ' equitable', ' grounded', ' Lent']
# Value vec: Layer 18, index 1961
# ['Spons', ' beneficiaries', 'ARI', ' Fav', 'ftime', 'owe', ' plum', 'ierre', ' encouragement', 'Export']
# Value vec: Layer 21, index 868
# ['s', 'a', 'inventory', 'gar', 'some', 'source', 'save', 'code', 'old', 'new']
# Value vec: Layer 17, index 1066
# ['advertising', 'trial', 'Whe', 'favorite', 'three', 'Republican', 'eight', 'Jewish', 'unit', 'five']
# Value vec: Layer 19, index 228
# [' portraits', ' portrait', ' wallpaper', ' souven', ' artwork', ' greeting', ' logo', ' Holiday', ' commemor', ' Christmas']
# Value vec: Layer 11, index 4048
# [' Commentary', ' Lauder', ' COMMUN', 'ieu', ' "$:/', ' Destination', '��', ' CST', 'FUL', 'holiday']
# Value vec: Layer 4, index 2769
# ['warm', 'war', ' pestic', 'ker', 'arer', 'gyn', 'Ber', 'hawk', 'arers', 'duc']
# Value vec: Layer 9, index 3553
# ['ocker', 'sama', 'Overview', ' �', 'Oper', 'oin', 'itary', 'aptop', 'fman', '♦']
# Value vec: Layer 16, index 3353
# [' resilient', ' intact', ' safegu', ' vigil', ' vigilance', ' faithfully', 'keep', ' safeguard', 'rup', 'Keep']
# Value vec: Layer 23, index 224
# [' Prediction', ' Uniform', 'TextColor', ' Memory', ' general', ' ILCS', 'Merit', '20439', ' START', ' ward']
# Value vec: Layer 19, index 2104
# ['ply', 'stad', 'ps', 'ker', 'quel', 'ventus', 'tw', 'factor', 'phase', 'eno']
# Value vec: Layer 14, index 1865
# ['lime', 'meter', 'fall', ' fins', 'mouth', 'mer', 'pron', 'lic', 'ingen', ' nodd']
# Value vec: Layer 5, index 781
# ['rogram', 'wrapper', 'Esc', 'riad', 'safe', 'eva', 'illi', 'agus', 'Install', 'pend']
# Value vec: Layer 23, index 3548
# ['yout', 'OVER', 'etsy', ' Puzz', 'wcs', 'resist', 'lvl', 'EMENT', 'aples', '314']
# Value vec: Layer 9, index 2795
# ['strap', ' Convert', 'mus', ' assum', 'atches', 'effective', 'plate', 'str', 'vol', 'iatus']
# Value vec: Layer 19, index 1307
# ['Tokens', 'ovych', 'eth', 'stown', ' Scholars', 'yne', 'tta', ' Scholar', 'reth', 'ilingual']
# Value vec: Layer 9, index 1845
# ['pa', 'inal', 'inter', 'mission', 'ness', 'bar', 'glass', 'wire', 'UI', 'ty']
# Value vec: Layer 13, index 974
# ['光', ' Millennium', 'Reviewed', 'moon', 'minded', ' nep', ' fellowship', 'AIDS', ' recomm', '^^^^']
# Value vec: Layer 7, index 3629
# ['pole', 'dogs', 'lie', 'dog', 'ig', 'ifier', 'board', 'coin', 'trade', 'ified']
# Value vec: Layer 23, index 1077
# ['oyer', 'minist', 'emale', 'imensional', ' Western', ' western', ' Jays', 'ppo', 'external', 'atum']
# Value vec: Layer 12, index 2102
# ['abl', ' yours', 'amazon', ' belie', 'eneg', ' convinced', 'ower', 'aah', 'mph', ' smile']
# Value vec: Layer 10, index 714
# [' taxp', 'abel', 'ato', ' upright', 'raq', 'adish', ' flush', ' functional', ' usable', ' Bacon']
# Value vec: Layer 21, index 2089
# ['aido', ' Spa', ' Signature', ' Shine', ' product', ' hype', ' spoiled', ' Cinderella', ' grind', ' sell']
# Value vec: Layer 19, index 3839
# ['Miss', 'Attempts', 'particularly', 'Egypt', 'Ex', 'Disc', 'per', 'Frank', 'Advertisement', 'currently']
# Value vec: Layer 17, index 2359
# ['ocument', 'unal', 'KN', 'anship', 'ACY', 'artz', 'foundation', 'hered', 'thood', 'aun']
# Value vec: Layer 5, index 3615
# ['urally', 'ensibly', 'ilater', 'RL', 'rador', 'auer', 'atron', 'arily', 'angu', 'assi']
# Value vec: Layer 14, index 559
# ['super', 'sub', 'second', 'small', 'new', 'nothing', 'document', 'normal', 'false', 'Sw']
# Value vec: Layer 17, index 3481
# ['teness', 'stant', 'ush', ' tumble', 'onica', 'rupal', 'oking', 'aily', 'atisf', 'uto']

# %%
target_vec = neg_embed - pos_embed

dot_prods = einsum("value_vecs d_model, d_model -> value_vecs", norm(value_vectors), target_vec)
top_value_vecs = dot_prods.topk(k=num_tp_vecs).indices

for vec_idx in top_value_vecs:
    print(f"Value vec: Layer {vec_idx // 4096}, index {vec_idx % 4096}")
    print(unembed_to_text(value_vectors[vec_idx], model, tokenizer))
# Out:
# Value vec: Layer 17, index 2953
# [' hate', ' hated', ' negativity', ' bad', ' dreaded', ' harmful', ' adversaries', ' enemies', ' harsh', 'enemy']
# Value vec: Layer 13, index 3214
# [' burdens', ' troubled', ' risks', ' misfortune', ' headache', ' trouble', ' risk', ' nightmare', ' adverse', ' toxicity']
# Value vec: Layer 17, index 1591
# [' inability', ' failed', ' unable', ' inadequate', ' lack', ' failing', ' lacking', ' failure', ' insufficient', ' fail']
# Value vec: Layer 17, index 443
# [' burdens', ' worst', ' worse', ' toxic', ' humiliating', ' waste', ' nightmare', ' pests', ' wasting', ' protracted']
# Value vec: Layer 16, index 974
# [' inappropriately', ' prejud', ' unnecessarily', ' improperly', ' unchecked', ' incorrectly', ' inefficient', ' miscon', ' arrogance', ' excessively']
# Value vec: Layer 20, index 1786
# [' problems', ' malfunction', ' failure', ' failures', ' damage', ' woes', ' dysfunction', ' trouble', ' injuries', ' damaged']
# Value vec: Layer 16, index 1643
# [' inability', ' ineffective', ' failed', ' insufficient', ' unable', 'failed', ' lose', ' failures', ' lackluster', ' fail']
# Value vec: Layer 16, index 889
# [' culprit', ' damaging', ' blamed', ' offending', ' guilty', ' harmful', ' blame', ' damages', ' ruin', ' severe']
# Value vec: Layer 15, index 3359
# [' jeopard', ' endanger', ' unlawfully', ' tresp', ' violations', ' infring', ' Worse', ' violates', ' damages', 'angering']
# Value vec: Layer 15, index 2187
# [' inconsistent', ' inconsistency', ' interference', ' incompatible', ' negativity', ' excessive', ' inequ', ' hind', ' misuse', ' mishand']
# Value vec: Layer 18, index 91
# [' unintentionally', ' errone', ' confused', ' bizarre', ' mistakenly', ' confusion', ' mis', ' incorrectly', ' mistaken', ' erroneous']
# Value vec: Layer 13, index 3280
# [' burdens', ' burden', ' difficulty', ' harsh', ' hardships', ' Worst', 'Sad', ' painful', 'stress', ' uncertainties']
# Value vec: Layer 14, index 220
# ['catentry', ' infringing', ' harmful', ' pitfalls', ' bitterness', ' rash', ' burdens', ' corrupt', 'ンジ', ' negativity']
# Value vec: Layer 16, index 757
# [' complications', ' pitfalls', ' risks', ' problems', ' Problems', ' anxiety', ' headaches', 'problem', ' conflicts', ' issues']
# Value vec: Layer 13, index 690
# [' hind', ' prejud', ' jeopard', ' Worse', ' infring', ' damaging', ' mishand', ' misrepresent', ' harmful', ' incompatible']
# Value vec: Layer 15, index 3278
# [' negatives', ' detract', ' disadvantages', ' lows', ' disadvantage', 'Weak', ' downside', ' detrim', ' downfall', ' negative']
# Value vec: Layer 14, index 1720
# [' harmful', ' damaging', ' nasty', ' malicious', ' disturbing', ' detrimental', ' menace', ' harming', ' destructive', ' nightmares']
# Value vec: Layer 13, index 1001
# [' fails', ' fail', ' dimin', ' miss', ' imperfect', ' doubtful', ' failed', ' disappoint', ' unsu', ' missed']
# Value vec: Layer 20, index 3723
# ['etheless', ' scen', ' reconc', ' releg', ' redes', ' merit', ' concern', ' conscientious', ' turbulence', ' precaution']
# Value vec: Layer 23, index 1744
# [' Nuggets', ' Wasteland', ' SAM', ' Trident', ' wishing', ' payday', ' sleeper', ' Indianapolis', ' independ', ' measures']
# Value vec: Layer 16, index 2204
# [' congest', ' hurts', ' insecure', ' sluggish', ' careless', ' troublesome', ' woes', ' inefficient', 'affected', ' overcrowd']
# Value vec: Layer 12, index 2756
# [' burdens', ' bad', ' offending', ' horrible', ' imped', ' glare', ' terrible', ' negativity', ' horrendous', ' aversion']
# Value vec: Layer 19, index 2930
# ['lessness', 'less', 'LESS', ' suppression', ' reductions', ' reduction', ' deval', ' diminished', ' reduced', ' impover']
# Value vec: Layer 16, index 3933
# [' panic', ' neglect', ' vain', ' arbitrary', ' disregard', ' shortcuts', ' bankrupt', ' selfish', ' blind', ' defaults']
# Value vec: Layer 15, index 3658
# [' Worse', ' handic', ' cripp', ' demise', ' inconvenient', ' embarrassing', ' Worst', ' limb', ' unlucky', ' havoc']
# Value vec: Layer 15, index 480
# [' failures', ' failed', ' failure', 'fail', ' failing', 'failed', ' unsuccessful', ' lose', ' fail', ' lost']
# Value vec: Layer 5, index 2384
# [' absentee', ' airborne', 'catentry', ' bearded', ' durable', ' aggressive', ' preval', ' layered', ' cro', ' emanc']
# Value vec: Layer 13, index 61
# [' Worse', ' failing', ' lackluster', ' lack', ' Lack', ' :(', ' ineffective', ' unfit', ' inability', 'Sorry']
# Value vec: Layer 22, index 603
# [' compan', ' streng', ' scen', ' sovere', ' skelet', ' municip', ' proble', ' ceremonial', ' divers', ' charact']
# Value vec: Layer 0, index 713
# ['senal', 'tten', 'BUG', ' addicted', ' dreaming', ' tired', ' reckoned', ' suppose', ' imagined', 'cooked']
# Value vec: Layer 15, index 2812
# ['need', ' NEED', ' need', ' needing', ' needed', 'problem', ' required', 'needs', ' Required', ' require']
# Value vec: Layer 13, index 2838
# [' burdens', ' awkward', ' darkness', ' cumbers', ' stale', ' dil', ' caveats', ' thorn', ' pitfalls', ' bog']
# Value vec: Layer 18, index 53
# [' Engels', ' blackmail', 'ppings', ' Krugman', ' neoliberal', ' arsen', ' 1926', ' sch', ' Qian', ' Muss']
# Value vec: Layer 21, index 3746
# [' disgust', ' abhor', 'ACC', ' shame', 'av', ' sob', 'anwhile', ' Civ', 'SHARE', ' Assembly']
# Value vec: Layer 12, index 2145
# [' exacerbate', ' exacerb', ' intensify', ' Bucc', 'agents', ' Lieberman', ' Incarn', ' wre', ' Gren', ' disturb']
# Value vec: Layer 14, index 1573
# [' interrupt', ' Passage', ' winters', ' displeasure', ' fear', ' complained', ' jealousy', ' Exception', ' NOTICE', ' notice']
# Value vec: Layer 14, index 357
# ['lessness', 'less', ' Unknown', ' nowhere', ' rejects', ' excluded', ' skept', ' exclusion', ' Darkness', ' poorly']
# Value vec: Layer 18, index 2724
# [' surpr', ' thous', ' scalp', ' notor', ' sovere', ' hardness', ' agre', ' insol', ' behav', ' advantageous']
# Value vec: Layer 18, index 3981
# [' wrong', ' incorrect', ' inaccurate', ' inadequate', ' misleading', ' outdated', ' misplaced', ' stale', ' ineffective', ' insufficient']
# Value vec: Layer 17, index 2366
# [' Gork', 'REF', '=~', ' Huss', 'PUT', ' Yiannopoulos', ' manifesto', ' inco', ' Bok', 'rentice']
# Value vec: Layer 18, index 2298
# [' Citation', ' Takeru', ' Accuracy', ' Brands', ' Ys', ' Yi', ' Qian', ' FIRE', ' UCHIJ', ' Texas']
# Value vec: Layer 23, index 3177
# [' mathemat', ' streng', ' strugg', 'etheless', ' incent', ' nodd', ' curtail', ' negligence', ' separation', ' reluct']
# Value vec: Layer 10, index 1276
# [' extensive', ' elaborate', ' ambitious', ' unfortunate', ' accurate', ' egregious', ' effective', ' interestingly', ' unnatural', ' emph']
# Value vec: Layer 13, index 3230
# [' aggress', ' malicious', ' bullies', ' hostile', ' ambush', ' hostility', ' agents', ' harass', ' retaliation', ' attacks']
# Value vec: Layer 8, index 1257
# [' misuse', ' mishand', ' scandals', ' errors', ' senseless', ' violations', ' insol', ' contamin', ' disproportion', ' congest']
# Value vec: Layer 2, index 3331
# [' autop', ' Greenpeace', ' monitoring', ' Trend', ' Panasonic', ' RESP', ' PAY', ' trending', ' tracker', ' pipeline']
# Value vec: Layer 17, index 966
# [' defending', 'venge', ' victory', ' fought', ' victories', ' skirm', ' battles', ' attacking', ' victorious', ' vict']
# Value vec: Layer 17, index 2696
# [' scrutiny', ' indictment', 'Prosecutors', ' audit', ' audits', ' Inquiry', ' probes', ' scandal', 'Court', ' investigators']
# Value vec: Layer 18, index 497
# [' warnings', ' vigilance', ' warning', ' WARNING', ' warn', 'warn', ' bans', ' Warning', ' condem', ' precaution']
# Value vec: Layer 13, index 1023
# [' vicious', ' humiliation', ' contempt', ' wasted', ' misery', ' sabotage', ' starving', ' sabot', ' shameless', ' extortion']
# Value vec: Layer 22, index 1268
# ['qus', ' boil', 'borne', '◼', 'gi', 'og', ' stumbling', 'zon', 'cano', ' tatt']
# Value vec: Layer 21, index 2477
# [' aver', ' beat', ' avoided', ' judgment', ' padd', ' ob', ' packs', ' stacks', ' bag', ' chains']
# Value vec: Layer 13, index 1128
# ['��', ' biochemical', ' calculus', ' chimpanzees', ' radical', ' remnant', ' microw', ' furry', ' prov', ' mass']
# Value vec: Layer 5, index 2395
# [' inexper', ' disproportion', ' therap', ' fixation', ' unsafe', ' unhealthy', ' summers', ' aggress', ' toile', ' unacceptable']
# Value vec: Layer 12, index 1321
# [' scandals', ' disclosures', ' disclosed', ' allegations', ' scandal', ' discl', ' bombshell', ' revelations', ' subpoen', ' allegation']
# Value vec: Layer 19, index 869
# ['arest', ' visceral', ' nuanced', ' depictions', ' blunt', ' vivid', ' penetrating', ' harrowing', ' powerfully', ' dense']
# Value vec: Layer 11, index 2389
# [' discoveries', ' breaches', ' anomalies', ' Proposition', ' annexation', ' STD', '��', ' errors', ' failings', 'GBT']
# Value vec: Layer 10, index 1562
# [' ext', ' acron', ' legislatures', ' nowadays', 'rities', 'mbuds', 'acists', 'hips', 'sworth', ' armies']
# Value vec: Layer 8, index 108
# ['ヘラ', ' Gleaming', ' maneuvers', ' mathemat', ' distilled', ' 裏覚醒', ' traged', 'rift', 'ZA', 'mercial']
# Value vec: Layer 18, index 3394
# [' axes', ' uncom', ' inefficient', ' unfl', ' axe', ' involuntary', ' undercut', ' irreversible', 'bryce', ' breaches']
# Value vec: Layer 17, index 320
# [' damaging', ' destabil', ' reck', ' violate', ' harming', ' endanger', ' interfere', ' unintentionally', ' violates', ' harm']
# Value vec: Layer 9, index 3636
# ['ンジ', ' tails', ' displ', ' inexper', ' embarrass', ' Hots', ' plateau', ' overhe', ' disadvantage', ' derivatives']
# Value vec: Layer 14, index 1379
# [' weeds', ' discipline', ' bother', ' pecul', ' obscurity', ' precaution', ' trouble', 'acus', ' controversy', ' sharks']
# Value vec: Layer 20, index 3069
# [' fringe', ' Extrem', ' extremist', 'hedon', ' nut', ' extremists', ' nuts', ' lun', ' nat', ' far']
# Value vec: Layer 17, index 2011
# [' Shape', ' Gors', ' Beir', ' mater', ' Pigs', ' pree', ' Grande', ' questionnaire', ' Triangle', ' subclass']
# Value vec: Layer 22, index 3227
# [' march', ' Citizens', ' Greenpeace', ' groups', ' peaceful', ' boycot', ' outraged', ' pro', ' activist', ' protester']
# Value vec: Layer 22, index 586
# [' P', ' Acc', ' Port', ' B', ' Q', ' Hub', ' Sm', ' L', ' Pic', ' PS']
# Value vec: Layer 14, index 1671
# ['itia', 'iann', ' ethics', ' Carbuncle', 'icative', ' Chao', ' ├', ' Leilan', ' Recomm', 'ettes']
# Value vec: Layer 15, index 3244
# [' Peb', ' Buildings', ' Implement', ' Presidential', 'OWS', 'アル', ' FW', '三', 'ARB', '�']
# Value vec: Layer 16, index 2908
# [' limitation', ' barrier', ' prohib', ' limit', ' restrictions', ' limiting', ' imped', ' restrictive', ' restriction', ' barriers']
# Value vec: Layer 17, index 287
# ['avier', 'kHz', ' kHz', '00', ' Opp', ' paced', '999', '�', '4000', ' opposite']
# Value vec: Layer 22, index 3047
# ['itone', 'itar', 'itu', '��', 'itary', 'itarian', 'igun', 'ibi', 'ilit', 'ected']
# Value vec: Layer 18, index 414
# [' bilingual', ' sight', ' overload', ' redundant', ' leaflets', ' groom', ' overloaded', ' supervised', ' pedigree', ' recogn']
# Value vec: Layer 23, index 823
# [' Mus', ' God', ' Prince', ' Star', ' West', ' Him', ' Middle', ' Argent', ' Holy', ' Mad']
# Value vec: Layer 3, index 29
# [' indisc', ' insin', ' paranoia', ' loyal', ' boasting', ' suspicious', ' coward', ' maniac', ' waves', ' flirt']
# Value vec: Layer 11, index 1202
# [' quota', 'pired', ' plateau', 'pire', ' exhaustion', ' sufficiently', ' exhaust', ' exhausted', 'letcher', 'enough']
# Value vec: Layer 4, index 3316
# [' observational', 'ormal', ' oral', ' inaction', ' medicinal', ' esc', ' Permanent', ' PHOTO', ' initiative', ' occupational']
# Value vec: Layer 17, index 2433
# [' ceased', ' nowhere', ' discouraged', ' decline', ' ineffective', ' unable', ' declines', 'none', ' vanish', ' cessation']
# Value vec: Layer 15, index 2112
# [' disease', ' diseases', ' infection', ' Disease', ' infections', ' illness', ' Diseases', ' alcoholism', ' malaria', ' contagious']
# Value vec: Layer 17, index 3206
# ['ocard', ' Employees', ' Daughter', ' Wife', 'owler', ' Teacher', 'acher', ' Customers', ' School', ' Santa']
# Value vec: Layer 17, index 3704
# [' misogyny', ' sexism', ' patriarchy', ' sexist', ' misogyn', ' homophobia', ' gender', 'femin', ' feminists', ' rape']
# Value vec: Layer 21, index 504
# [' leaps', ' graphene', ' waiver', ' println', ' \xad', ' grate', ' [[', ' ff', ' assembly', ' incumb']
# Value vec: Layer 19, index 988
# [' merciless', 'FontSize', '20439', ' relentlessly', ' vicious', ' relentless', 'ruciating', ' horrifying', ' terrifying', 'blooded']
# Value vec: Layer 10, index 3270
# [' dece', ' offending', ' offenders', ' abuses', ' crimes', ' persecut', ' perpetrators', ' offenses', ' offences', ' attacks']
# Value vec: Layer 14, index 836
# [' inadequate', 'fail', ' unsu', ' disappoint', ' failing', 'Poor', ' failure', ' excuses', ' lame', ' inadequ']
# Value vec: Layer 17, index 242
# ['onement', 'aminer', 'iversary', 'ensation', 'pas', 'danger', '闘', 'der', 'ager', ' emergencies']
# Value vec: Layer 22, index 1572
# ['ifer', 'ּ', 'enaries', 'orsi', 'oreal', 'urrection', ' impover', 'usterity', ' valve', 'ansion']
# Value vec: Layer 17, index 4075
# ['sbm', '�', ' lich', ' simultane', 'ーン', ' Functional', '�', ' Grove', ' Rend', ' Fut']
# Value vec: Layer 0, index 1577
# [' handc', ' 2048', 'inx', 'alloc', '五', 'ck', 'ーン', 'ENCY', 'zona', 'TPS']
# Value vec: Layer 9, index 3704
# [' misleading', ' unfairly', ' hypocritical', ' unfair', 'angering', ' irresponsible', ' inaccurate', ' misrepresent', ' Mata', ' biased']
# Value vec: Layer 12, index 1483
# [' complains', ' complaining', ' backlash', 'Problem', ' protesting', ' complaints', ' complain', ' complained', ' complaint', '�']
# Value vec: Layer 13, index 998
# [' illnesses', ' symptoms', ' harms', ' illness', ' threats', ' spills', ' malicious', ' attacks', 'Charges', ' Attacks']
# Value vec: Layer 12, index 500
# ['oulos', ' dou', ' contempt', ' fut', 'ueless', ' mockery', 'stros', ' corros', ' humiliation', ' misery']
# Value vec: Layer 20, index 2259
# ['azer', ' ze', 'lik', 'ilt', 'se', ' sold', 'oros', 'atches', 'ubis', 'ZE']
# Value vec: Layer 16, index 1420
# [' inadequate', ' insufficient', ' ineffective', ' inefficient', ' limited', ' inability', ' useless', ' inadequ', ' unsatisf', ' incomplete']
# Value vec: Layer 18, index 4095
# ['iping', 'arding', 'ginx', 'lli', '��', 'ipple', 'illi', 'デ', 'ractor', 'lling']
# Value vec: Layer 8, index 977
# [' Surv', 'dfx', ' CW', ' Staples', 'UV', ' compet', ' prejud', ' transmission', ' Extrem', 'spe']
# Value vec: Layer 16, index 315
# [' generous', ' expensive', ' intense', ' dense', ' ambitious', ' powerful', ' complicated', ' difficult', ' valuable', ' costly']
# Value vec: Layer 16, index 1169
# [' summar', ' succinct', ' scathing', ' eloqu', ' written', ' pamphlet', ' remarks', ' texts', ' explaining', ' Editorial']
# Value vec: Layer 10, index 3288
# ['accompan', ' orn', ' Cust', ' destro', ' pend', ' stains', ' Williamson', ' impatient', ' ingred', ' Plat']
